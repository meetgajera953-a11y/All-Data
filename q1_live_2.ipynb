# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("WebTraffic_Q1_2025.csv")
df
# Out:
#       VisitDate  SessionDuration  PageViews  ReferralSource DeviceType  \
# 0    2025-03-17           140.78        3.0        Referral     Tablet
# 1    2025-01-03           903.04        3.0     Paid Search     Tablet
# 2    2025-02-25           395.02        5.0    Social Media     Mobile
# 3    2025-01-29           273.88        6.0        Referral    Desktop
# 4    2025-03-23            50.89        5.0  Organic Search     Mobile
# ..          ...              ...        ...             ...        ...
# 595  2025-02-19           192.71        4.0  Organic Search     Mobile
# 596  2025-03-15           330.39        3.0    Social Media    Desktop
# 597  2025-01-14            56.74        6.0  Organic Search     Mobile
# 598  2025-01-14            64.07        4.0    Social Media     Mobile
# 599  2025-02-04            12.52        2.0          Direct    Desktop
#
#     Platform  BounceRate  Conversions
# 0    Windows       88.24            1
# 1    Windows       48.78            0
# 2      macOS       51.13            0
# 3      macOS       60.36            0
# 4      Linux       88.83            1
# ..       ...         ...          ...
# 595    Linux       58.28            0
# 596      iOS       58.24            0
# 597    macOS       26.26            0
# 598    macOS       49.26            0
# 599      iOS       79.73            0
#
# [600 rows x 8 columns]

# %%
df[df.isnull().any(axis=1)]

# %%
df.columns

# %%
df.isnull().sum()

# %%
df.dtypes

# %%
df["Sales"] = df["Sales"].fillna(df["Sales"].mean())
df["Revenue"] = df["Revenue"].fillna(df["Revenue"].mean())

# %%
df.isnull().sum()
# Out:
# VisitDate           0
# SessionDuration    12
# PageViews           9
# ReferralSource      0
# DeviceType          0
# Platform            0
# BounceRate          0
# Conversions         0
# dtype: int64

# %%
df["VisitDate"] = pd.to_datetime(df["VisitDate"])
df
# Out:
#      VisitDate  SessionDuration  PageViews  ReferralSource DeviceType  \
# 0   2025-03-17           140.78        3.0        Referral     Tablet
# 1   2025-01-03           903.04        3.0     Paid Search     Tablet
# 2   2025-02-25           395.02        5.0    Social Media     Mobile
# 3   2025-01-29           273.88        6.0        Referral    Desktop
# 4   2025-03-23            50.89        5.0  Organic Search     Mobile
# ..         ...              ...        ...             ...        ...
# 595 2025-02-19           192.71        4.0  Organic Search     Mobile
# 596 2025-03-15           330.39        3.0    Social Media    Desktop
# 597 2025-01-14            56.74        6.0  Organic Search     Mobile
# 598 2025-01-14            64.07        4.0    Social Media     Mobile
# 599 2025-02-04            12.52        2.0          Direct    Desktop
#
#     Platform  BounceRate  Conversions
# 0    Windows       88.24            1
# 1    Windows       48.78            0
# 2      macOS       51.13            0
# 3      macOS       60.36            0
# 4      Linux       88.83            1
# ..       ...         ...          ...
# 595    Linux       58.28            0
# 596      iOS       58.24            0
# 597    macOS       26.26            0
# 598    macOS       49.26            0
# 599      iOS       79.73            0
#
# [600 rows x 8 columns]

# %%
df["Month"] = df["Date"].dt.month
df["Year"] = df["Date"].dt.year
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\RW\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df["Month"] = df["Date"].dt.month
#       2 df["Year"] = df["Date"].dt.year
#
# File c:\Users\RW\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File c:\Users\RW\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'Date'

# %%
df

# %%
df.duplicated().sum() # 5 rows are duplicated hence remove
df.drop_duplicates(inplace=True) # now 500 rows from 505

# %%
stats_summary = df[["Sales","Revenue","Quantity"]].describe()
stats_summary

# %%
corr_matrix = df[["Sales","Revenue","Quantity"]].corr()
corr_matrix

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# plt.figure(figsize=(7,3))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()

# %%
df.sample(3)

# %%
top_5 = df.groupby(by="Product")["Revenue"].sum().nlargest(5)
top_5

# %%
top_5.plot(kind="bar")
plt.title("Top 5 Products")
plt.xlabel('Product')
plt.ylabel('Revenue')
plt.show()

# %%
sales_montly = df.groupby(by="Month")["Sales"].sum()
sales_montly

# %%
sales_montly.plot(kind="line", marker="o")
plt.title('Monthly Sales Trend in Q1')
plt.xlabel('Month')
plt.ylabel('Sales')

# %%
max = sales_montly.idxmax()
min = sales_montly.idxmin()

max

# %%
region_revenue = df.groupby(by="Region")["Revenue"].sum()
region_revenue

# %%
region_revenue.plot(kind="bar")
plt.title('Total Revenue per Region')
plt.xlabel('Region')
plt.ylabel('Revenue')
plt.show()

high_region = region_revenue.idxmax()
high_sales = region_revenue.max()
print(f'The region with the highest sales is {high_region} with a revenue of {high_sales}.')

# %%
customer_data_sales= df.groupby('CustomerID')["Sales"].count()
customer_data_revenue = df.groupby('CustomerID')["Revenue"].mean()

# %%
a = pd.DataFrame(customer_data_sales)
b = pd.DataFrame(customer_data_revenue)
new_data = pd.merge(a,b,on="CustomerID")
new_data
